# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pnt
import seaborn as sns
from sklearn.model_selection import train_test_split
from pandas.core.common import random_state
from sklearn.linear_model import LinearRegression

# %%
df_sal = pd.read_csv("//home//primes//Documents//COOPERATIVE UNIVERSITY OF KENYA//4.1//MACHINE-LEARNING//Salary_Data.csv")

# %%
df_sal.head(10)
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0
# 5              2.9  56642.0
# 6              3.0  60150.0
# 7              3.2  54445.0
# 8              3.2  64445.0
# 9              3.7  57189.0

# %%
df_sal.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
pnt.title('Salary Distribution')
sns.distplot(df_sal['Salary'])
pnt.show()
# Out:
# /tmp/ipykernel_5134/324456484.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_sal['Salary'])

# %%
pnt.scatter(df_sal['YearsExperience'], df_sal['Salary'], color = 'lightcoral')
pnt.title('Salary VS YearsExperience')
pnt.xlabel('YearsExperience')
pnt.ylabel('Salary')
pnt.show()

# %%
x = df_sal.iloc[:, :1]
y = df_sal.iloc[:, 1:]
